# %% [markdown]
# <a href="https://colab.research.google.com/github/GregoSX/EFC1-CPA/blob/main/EFC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EFC1 GCC253 - Complexidade e Projeto de Algoritmos - 5 pontos.
#
#
# > **Prof.: Douglas H. S. Abreu**
#
#
# **Integrantes**:
#
# - Guilherme Grego Santos - 202020417
# - Lucas Neves Saber Gabriel - 202020459
# - Otávio Augusto Trindade Fonseca - 202020551
# - Thiago Odilon de Almeida - 202021025
#
# **Turma**: 10A
#
# Link do repositório GitHub: https://github.com/GregoSX/EFC1-CPA.git
#
# ● O trabalho deve ser feito em grupos de no máximo 4 componentes (Apenas um deve enviar a atividade no Campus Virtual)
#
# ● Trabalhos entregues após a data limite não serão aceitos
#
# ● Data limite de entrega: 20 de Novembro de 2022 : 23h55m
#
# ● Enviar o trabalho para o campus virtual, do seguinte modo: link do repositório GitHub com acesso ao Notebook.
#
# ● O trabalho deve ser desenvolvido no modelo Notebook utilizando preferencialmente a linguagem Python

# %% [markdown]
# # Funções de Ordenação

# %% [markdown]
# ##  Insertion Sort

# %%
import random

def InsertionSort(vetor):
  for j in range(1, len(vetor)):
    chave = vetor[j]
    i = j-1
    while i >= 0 and vetor[i] > chave:
      vetor[i+1] = vetor[i]
      i = i - 1
    vetor[i+1] = chave

vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

InsertionSort(vetor1)
InsertionSort(vetor2)
InsertionSort(vetor3)

print("Vetor 1 ordenado = ", vetor1)
print("Vetor 2 ordenado = ", vetor2)
print("Vetor 3 ordenado = ", vetor3)
# Out:
# Vetor 1 ordenado =  [-15, -12, -11, -10, -9]
# Vetor 2 ordenado =  [-4, -3, 2, 3, 4]
# Vetor 3 ordenado =  [7, 8, 9, 12, 14]

# %% [markdown]
# ##  Merge Sort

# %%
import random

def merge(vetor, p, q, r):
  n1 = q - p + 1 
  n2 = r - q
  l = [0] * n1
  r = [0] * n2

  for i in range(0,n1):
    l[i] = vetor[p + i]

  for j in range(0,n2):
    r[j] = vetor[q + 1 + j]

  i, j = 0, 0
  k = p
  while i < n1 and j < n2:
    if l[i] <= r[j]:
      vetor[k] = l[i]
      i += 1
    else:
      vetor[k] = r[j]
      j += 1
    k += 1
  while i < n1:
    vetor[k] = l[i]
    i += 1
    k += 1
  while j < n2:
    vetor[k] = r[j]
    j += 1
    k += 1

def mergeSort(arranjo,p,r):
  if p < r:
    q = (p + r) // 2
    mergeSort(arranjo,p,q)
    mergeSort(arranjo,q + 1,r)
    merge(arranjo,p,q,r)
  
  return arranjo

vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

mergeSort(vetor1, 0, len(vetor1) - 1)
mergeSort(vetor2, 0, len(vetor2) - 1 )
mergeSort(vetor3, 0, len(vetor3) - 1)

print("Vetor 1 ordenado = ", vetor1)
print("Vetor 2 ordenado = ", vetor2)
print("Vetor 3 ordenado = ", vetor3)
# Out:
# Vetor 1 ordenado =  [-14, -13, -12, -8, -7]
# Vetor 2 ordenado =  [-4, -3, -1, 2, 4]
# Vetor 3 ordenado =  [6, 7, 9, 12, 13]

# %% [markdown]
# ##  Selection Sort

# %%
import random

def SelectionSort(Array):
  tam = len(Array)
  for i in range(tam):
    menor = i
    for j in range(i + 1, tam):
      if (Array[menor] > Array[j]):
        menor = j
    temp = Array[i]
    Array[i] = Array[menor]
    Array[menor] = temp

vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

SelectionSort(vetor1)
SelectionSort(vetor2)
SelectionSort(vetor3)

print("Vetor 1 ordenado = ", vetor1)
print("Vetor 2 ordenado = ", vetor2)
print("Vetor 3 ordenado = ", vetor3)
# Out:
# Vetor 1 ordenado =  [-15, -14, -13, -10, -6]
# Vetor 2 ordenado =  [-3, -1, 0, 3, 4]
# Vetor 3 ordenado =  [7, 8, 10, 12, 13]

# %% [markdown]
# ##  Bubble Sort

# %%
import random

def bubbleSort(Array):
    tam = len(Array)-1
    for n in range(tam):
        for i in range(0, tam-n):
            if Array[i] > Array[i+1]:
                temp = Array[i]
                Array[i] = Array[i+1]
                Array[i+1] = temp


vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

bubbleSort(vetor1)
bubbleSort(vetor2)
bubbleSort(vetor3)

print("Vetor 1 ordenado: ", vetor1)
print("Vetor 2 ordenado: ", vetor2)
print("Vetor 3 ordenado: ", vetor3)
# Out:
# Vetor 1 ordenado:  [-15, -12, -11, -8, -6]
# Vetor 2 ordenado:  [-4, -3, 2, 3, 4]
# Vetor 3 ordenado:  [7, 9, 10, 13, 14]

# %% [markdown]
# ## Heap Sort

# %%
import random

def heapfy(vetor, n, i):
  maior = i;
  esq = 2 * i + 1
  dir = 2 * i + 2

  if esq < n and vetor[maior] < vetor[esq]:
    maior = esq

  if dir < n and vetor[maior] < vetor[dir]:
    maior = dir

  if maior != i:
    vetor[i], vetor[maior] = vetor[maior], vetor[i]
    heapfy(vetor, n, maior)

def heapSort(vetor):
  n = len(vetor)

  for i in range(n//2-1,-1,-1):
    heapfy(vetor,n,i)

  for i in range(n-1, 0, -1):
    vetor[i], vetor[0] = vetor[0], vetor[i]
    heapfy(vetor, i, 0)
  
  return vetor

vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

heapSort(vetor1)
heapSort(vetor2)
heapSort(vetor3)

print("Vetor 1 ordenado = ", vetor1)
print("Vetor 2 ordenado = ", vetor2)
print("Vetor 3 ordenado = ", vetor3)
# Out:
# Vetor 1 ordenado =  [-13, -10, -9, -7, -6]
# Vetor 2 ordenado =  [-2, 1, 2, 3, 4]
# Vetor 3 ordenado =  [7, 8, 11, 13, 14]

# %% [markdown]
# ## Quick Sort com pivo sendo o ultimo elemento do arranjo
#
# > pivo = *A[A-comprimento]*

# %%
def particao(arranjo, ini, fim):
  pivo = arranjo[fim]
  i = ini - 1

  for j in range(ini, fim):
    if arranjo[j] <= pivo:
      i = i + 1
      (arranjo[i], arranjo[j]) = arranjo[j], arranjo[i]

  arranjo[i + 1], arranjo[fim] = arranjo[fim], arranjo[i + 1]

  return i + 1

def quickSort(arranjo, ini, fim):
  if ini < fim:
    pi = particao(arranjo, ini, fim)
    quickSort(arranjo, ini, pi - 1)
    quickSort(arranjo, pi + 1, fim)

  return arranjo

vetor1 = random.sample(range(-15, -5), 5)
vetor2 = random.sample(range(-4, 5), 5)
vetor3 = random.sample(range(6, 15), 5)

quickSort(vetor1, 0, len(vetor1) - 1)
quickSort(vetor2, 0, len(vetor2) - 1)
quickSort(vetor3, 0, len(vetor3) - 1)

print("Vetor 1 ordenado = ", vetor1)
print("Vetor 2 ordenado = ", vetor2)
print("Vetor 3 ordenado = ", vetor3)
# Out:
# Vetor 1 ordenado =  [-15, -14, -12, -11, -8]
# Vetor 2 ordenado =  [-4, -3, -1, 2, 4]
# Vetor 3 ordenado =  [6, 9, 11, 13, 14]

# %% [markdown]
# # Questões

# %% [markdown]
# 1.   Escolha pelo menos 3 arranjos. Ex: ***A[5,...,1000,...,100]*** e mostre o funcionamento dos Algoritmos realizando a ordenação.

# %% [markdown]
# ![insertion-sort.png](data:image/png;base64,...)

# %% [markdown]
# ![ccpa.drawio (1).png](data:image/png;base64,...)

# %%
print("Boa sorte!!!")
# Out:
# Boa sorte!!!
